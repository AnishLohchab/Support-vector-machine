# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\Anish\Downloads\Iris.csv")

# %%
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
X = dataset.iloc[:,0:5]       #independent variable ko alag kra h humne yhape

# %%
y = dataset.iloc[:,5]            #dependent variable ko alag kra h humne yhape.

# %%
X            #independent variable
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
y                  #dependent variable
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
# abh hume apne dataset kp split krna h 
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
len(X_train)
# Out:
# 120

# %%
len(X_test)
# Out:
# 30

# %%
# abh hume SVM implement krna h.
from sklearn.svm import SVC     #svc -> support vector classifier

# %%
model = SVC(kernel = 'linear')         #kernel is an parameter # svm do type ke hote h linear and non linear
                                       #kernel : {'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'} bydefault = rbf

# %%
#abh hum fit method ki help se model ko train krnenge.
model.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
# abh humara moedl train ho chuka h and abh puri tarah se raedy h prediction krne k liye
model.predict(X_test)
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-setosa', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-virginica', 'Iris-virginica', 'Iris-virginica'], dtype=object)

# %%
X_test
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 45    46            4.8           3.0            1.4           0.3
# 11    12            4.8           3.4            1.6           0.2
# 149  150            5.9           3.0            5.1           1.8
# 87    88            6.3           2.3            4.4           1.3
# 31    32            5.4           3.4            1.5           0.4
# 18    19            5.7           3.8            1.7           0.3
# 8      9            4.4           2.9            1.4           0.2
# 14    15            5.8           4.0            1.2           0.2
# 112  113            6.8           3.0            5.5           2.1
# 40    41            5.0           3.5            1.3           0.3
# 2      3            4.7           3.2            1.3           0.2
# 114  115            5.8           2.8            5.1           2.4
# 79    80            5.7           2.6            3.5           1.0
# ...

# %%
model.score(X_test,y_test)       #humaare model ka score aya h 100 percent.
# Out:
# 1.0
